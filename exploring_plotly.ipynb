# %% [markdown]
# https://medium.com/plotly/plotly-py-4-0-is-here-offline-only-express-first-displayable-anywhere-fc444e5659ee
#
# https://plotly.com/python/getting-started/

# %%
import plotly.graph_objects as go
import plotly.express as px

# %%
x = model2_results[which_scenario]['output']['profit']

fig = go.Figure(data=[go.Histogram(x=x)])
fig.show()

# %%
df = model2_results_df[model2_results_df['scenario_num'] == 4]
df
# Out:
#          profit  scenario_num  order_quantity
# 0      4.496767             4             270
# 1    -49.297293             4             270
# 2    115.325374             4             270
# 3   -652.543524             4             270
# 4    -64.893003             4             270
# ..          ...           ...             ...
# 995  444.020792             4             270
# 996  248.889455             4             270
# 997  -94.825335             4             270
# 998  429.704761             4             270
# 999   10.280155             4             270
#
# [1000 rows x 3 columns]

# %%
fig = px.histogram(df, x="profit")
fig.show()
